# %%
# import the tokenizer module
# access interface functions using tk
import tokenizer as tk

# %%
# Tokenize code lines on 'sample.art' source file
tokendf = tk.Tokenize('sample.art')
tokendf     # display tokenlist dataframe
# Out:
#     lineNumber  start      token               type
# 0            1      0     canvas             CANVAS
# 1            1      6          (  PARENTHESIS_START
# 2            1      7        100            INTEGER
# 3            1     10          ,          SEPARATOR
# 4            1     11         50            INTEGER
# 5            1     13          )    PARENTHESIS_END
# 6            2      0  Rectangle          RECTANGLE
# 7            2     10       rect         IDENTIFIER
# 8            3      0       rect         IDENTIFIER
# 9            3      4          .       DOT_NOTATION
# 10           3      5       size               SIZE
# 11           3      9          (  PARENTHESIS_START
# 12           3     10         10            INTEGER
# 13           3     12          ,          SEPARATOR
# 14           3     14         20            INTEGER
# 15           3     16          ,          SEPARATOR
# 16           3     18         20            INTEGER
# 17           3     20          ,          SEPARATOR
# 18           3     22         40            INTEGER
# 19           3     24          )    PARENTHESIS_END
# 20           4      0       rect         IDENTIFIER
# 21           4      4          .       DOT_NOTATION
# 22           4      5    outline            OUTLINE
# 23           4     12          (  PARENTHESIS_START
# 24           4     13          1            INTEGER
# 25           4     14          ,          SEPARATOR
# 26           4     16        rgb                RGB
# 27           4     19          (  PARENTHESIS_START
# 28           4     20          0            INTEGER
# 29           4     21          ,          SEPARATOR
# 30           4     22          0            INTEGER
# 31           4     23          ,          SEPARATOR
# 32           4     24          0            INTEGER
# 33           4     25          )    PARENTHESIS_END
# 34           4     26          ,          SEPARATOR
# 35           4     28         50            INTEGER
# 36           4     30          )    PARENTHESIS_END
# 37           5      0       rect         IDENTIFIER
# 38           5      4          .       DOT_NOTATION
# 39           5      5       fill               FILL
# 40           5      9          (  PARENTHESIS_START
# 41           5     10        rgb                RGB
# 42           5     13          (  PARENTHESIS_START
# 43           5     14          0            INTEGER
# 44           5     15          ,          SEPARATOR
# 45           5     16          0            INTEGER
# 46           5     17          ,          SEPARATOR
# 47           5     18          0            INTEGER
# 48           5     19          )    PARENTHESIS_END
# 49           5     20          ,          SEPARATOR
# 50           5     22         50            INTEGER
# 51           5     24          )    PARENTHESIS_END
