# %%
# import the tokenizer module
# access interface functions using tk
import tokenizer as tk   
from parse import Parse

# %%
# Tokenize code lines on 'sample.art' source file
tokendf = tk.Tokenize('sample.art')
tokendf     # display tokenlist dataframe
# Out:
#     lineNumber  start      token               type
# 0            1      0        def         IDENTIFIER
# 1            1      4   funcName         IDENTIFIER
# 2            1     12          (  PARENTHESIS_START
# 3            1     13          )    PARENTHESIS_END
# 4            1     14          {  CURLY_BRACE_START
# 5            2      0  Rectangle          RECTANGLE
# 6            2     10       rect         IDENTIFIER
# 7            3      0     Circle             CIRCLE
# 8            3      7       circ         IDENTIFIER
# 9            4      0         ab         IDENTIFIER
# 10           4      3          =          ASSIGN_OP
# 11           4      5          1            INTEGER
# 12           4      7          +      MATH_OPERATOR
# 13           4      9          2            INTEGER
# 14           5      0       rect         IDENTIFIER
# 15           5      4          .       DOT_NOTATION
# 16           5      5       size               SIZE
# 17           5      9          (  PARENTHESIS_START
# 18           5     10         10            INTEGER
# 19           5     12          ,          SEPARATOR
# 20           5     14         20            INTEGER
# 21           5     16          ,          SEPARATOR
# 22           5     18         20            INTEGER
# 23           5     20          ,          SEPARATOR
# 24           5     22         40            INTEGER
# 25           5     24          )    PARENTHESIS_END
# 26           6      0     circle         IDENTIFIER
# 27           6      6          .       DOT_NOTATION
# 28           6      7       size               SIZE
# 29           6     11          (  PARENTHESIS_START
# 30           6     12         50            INTEGER
# 31           6     14          ,          SEPARATOR
# 32           6     16         50            INTEGER
# 33           6     18          ,          SEPARATOR
# 34           6     20         20            INTEGER
# 35           6     22          )    PARENTHESIS_END
# 36           7      0        dot         IDENTIFIER
# 37           7      3          .       DOT_NOTATION
# 38           7      4       size               SIZE
# 39           7      8          (  PARENTHESIS_START
# 40           7      9         50            INTEGER
# 41           7     11          ,          SEPARATOR
# 42           7     13         50            INTEGER
# 43           7     15          )    PARENTHESIS_END
# 44           8      0          }    CURLY_BRACE_END

# %%
prMod = Parse('sample.art')
prMod.Parser()
# Out:
# expr
#   func
#     TOKEN='def'
#     TOKEN='funcName'
#     TOKEN='('
#     TOKEN=')'
#     TOKEN='{'
#     code
#       init
#         data_type
#           TOKEN='Rectangle'
#         TOKEN='rect'
#     code
#       init
#         data_type
#           TOKEN='Circle '
#         TOKEN='circ'
#     code
#       math_expr
#         TOKEN='ab'
#         TOKEN='='
#         computation
#           value_type
#             TOKEN='1'
#           TOKEN='+'
#           value_type
#             TOKEN='ab'
#     code
#       size_shape
#         TOKEN='rect'
#         TOKEN='.'
#         TOKEN='size'
#         TOKEN='('
#         params
#           two_params
#             value_type
#               TOKEN='10'
#             TOKEN=','
#             value_type
#               TOKEN='20'
#           TOKEN=','
#           two_params
#             value_type
#               TOKEN='20'
#             TOKEN=','
#             value_type
#               TOKEN='40'
#         TOKEN=')'
#     code
#       size_shape
#         TOKEN='circle'
#         TOKEN='.'
#         TOKEN='size'
#         TOKEN='('
#         params
#           two_params
#             value_type
#               TOKEN='50'
#             TOKEN=','
#             value_type
#               TOKEN='50'
#           TOKEN=','
#           value_type
#             TOKEN='20'
#         TOKEN=')'
#     code
#       size_shape
#         TOKEN='dot'
#         TOKEN='.'
#         TOKEN='size'
#         TOKEN='('
#         params
#           two_params
#             value_type
#               TOKEN='50'
#             TOKEN=','
#             value_type
#               TOKEN='50'
#         TOKEN=')'
#     TOKEN='}'
