# %%
# import the tokenizer module
# access interface functions using tk
import tokenizer as tk   
from parse import Parse

# %%
# Tokenize code lines on 'sample.art' source file
tokendf = tk.Tokenize('sample.art')
#tokendf     # display tokenlist dataframe

# %%
prMod = Parse('sample.art')
prMod.Parser()
# Out:
# line 1:15 extraneous input '{' expecting {RECTANGLE, SQUARE, CIRCLE, DOT, STRAIGHT, ARC, PIXEL, IF, FOR, CANVAS, IDENTIFIER, '}'}
# expr
#   func
#     TOKEN='def'
#     TOKEN='funcName'
#     TOKEN='('
#     TOKEN=')'
#     TOKEN='{'
#     TOKEN='{'
#     code
#       init
#         data_type
#           TOKEN='Rectangle'
#         TOKEN='rect'
#     code
#       init
#         data_type
#           TOKEN='Circle'
#         TOKEN='circ'
#     code
#       init_int
#         TOKEN='samp'
#         TOKEN='='
#         TOKEN='1'
#     code
#       func_call
#         TOKEN='func'
#         TOKEN='('
#         call_params
#           value_type
#             TOKEN='1'
#           TOKEN=','
#           value_type
#             TOKEN='2'
#           TOKEN=','
#           value_type
#             TOKEN='a'
#         TOKEN=')'
#     code
#       canvas_def
#         TOKEN='canvas'
#         TOKEN='('
#         two_params
#           value_type
#             TOKEN='100'
#           TOKEN=','
#           value_type
#             TOKEN='50'
#         TOKEN=')'
#     code
#       outline_def
#         TOKEN='rect'
#         TOKEN='.'
#         TOKEN='outline'
#         TOKEN='('
#         outline_params
#           value_type
#             TOKEN='1'
#           TOKEN=','
#           rgb_def
#             TOKEN='rgb'
#             TOKEN='('
#             two_params
#               value_type
#                 TOKEN='0'
#               TOKEN=','
#               value_type
#                 TOKEN='0'
#             TOKEN=','
#             value_type
#               TOKEN='0'
#             TOKEN=')'
#           TOKEN=','
#           value_type
#             TOKEN='50'
#         TOKEN=')'
#     code
#       draw_shape
#         TOKEN='line'
#         TOKEN='.'
#         TOKEN='draw'
#         TOKEN='('
#         draw_params
#           two_params
#             value_type
#               TOKEN='50'
#             TOKEN=','
#             value_type
#               TOKEN='50'
#           TOKEN=','
#           two_params
#             value_type
#               TOKEN='100'
#             TOKEN=','
#             value_type
#               TOKEN='50'
#         TOKEN=')'
#     code
#       fill_def
#         TOKEN='rect'
#         TOKEN='.'
#         TOKEN='fill'
#         TOKEN='('
#         fill_params
#           rgb_def
#             TOKEN='rgb'
#             TOKEN='('
#             two_params
#               value_type
#                 TOKEN='0'
#               TOKEN=','
#               value_type
#                 TOKEN='0'
#             TOKEN=','
#             value_type
#               TOKEN='0'
#             TOKEN=')'
#           TOKEN=','
#           value_type
#             TOKEN='50'
#         TOKEN=')'
#     code
#       size_shape
#         TOKEN='rect'
#         TOKEN='.'
#         TOKEN='size'
#         TOKEN='('
#         size_params
#           two_params
#             value_type
#               TOKEN='10'
#             TOKEN=','
#             value_type
#               TOKEN='20'
#           TOKEN=','
#           two_params
#             value_type
#               TOKEN='20'
#             TOKEN=','
#             value_type
#               TOKEN='40'
#         TOKEN=')'
#     code
#       if_else
#         if_cond
#           TOKEN='if'
#           condition
#             condition_base
#               TOKEN='('
#               condition_body
#                 value_type
#                   TOKEN='a'
#                 TOKEN='>'
#                 value_type
#                   TOKEN='b'
#               TOKEN=')'
#           ifel_body
#             TOKEN='{'
#             code
#               init
#                 data_type
#                   TOKEN='Rectangle'
#                 TOKEN='rectTwo'
#             TOKEN='}'
#         else_cond
#           TOKEN='else'
#           ifel_body
#             TOKEN='{'
#             code
#               init
#                 data_type
#                   TOKEN='Arc'
#                 TOKEN='arcOne'
#             TOKEN='}'
#     code
#       loop
#         TOKEN='for'
#         TOKEN='('
#         loop_init
#           init_int
#             TOKEN='samp'
#             TOKEN='='
#             TOKEN='1'
#           TOKEN=';'
#         loop_cond
#           condition_body
#             value_type
#               TOKEN='samp'
#             TOKEN='>'
#             value_type
#               TOKEN='5'
#           TOKEN=';'
#         loop_incdec
#           TOKEN='1'
#           TOKEN='++'
#         TOKEN=')'
#         loop_body
#           TOKEN='{'
#           code
#             init
#               data_type
#                 TOKEN='Rectangle'
#               TOKEN='sampl'
#           code
#             if_else
#               if_cond
#                 TOKEN='if'
#                 condition
#                   condition_base
#                     TOKEN='('
#                     condition_body
#                       value_type
#                         TOKEN='a'
#                       TOKEN='>'
#                       value_type
#                         TOKEN='b'
#                     TOKEN=')'
#                 ifel_body
#                   TOKEN='{'
#                   code
#                     init
#                       data_type
#                         TOKEN='Rectangle'
#                       TOKEN='rectTwo'
#                   TOKEN='}'
#               else_cond
#                 TOKEN='else'
#                 ifel_body
#                   TOKEN='{'
#                   code
#                     init
#                       data_type
#                         TOKEN='Arc'
#                       TOKEN='arcOne'
#                   code
#                     loop
#                       TOKEN='for'
#                       TOKEN='('
#                       loop_init
#                         init_int
#                           TOKEN='samp'
#                           TOKEN='='
#                           TOKEN='1'
#                         TOKEN=';'
#                       loop_cond
#                         condition_body
#                           value_type
#                             TOKEN='samp'
#                           TOKEN='>'
#                           value_type
#                             TOKEN='5'
#                         TOKEN=';'
#                       loop_incdec
#                         TOKEN='1'
#                         TOKEN='++'
#                       TOKEN=')'
#                       loop_body
#                         TOKEN='{'
#                         code
#                           init
#                             data_type
#                               TOKEN='Rectangle'
#                             TOKEN='sampl'
#                         code
#                           if_else
#                             if_cond
#                               TOKEN='if'
#                               condition
#                                 condition_base
#                                   TOKEN='('
#                                   condition_body
#                                     value_type
#                                       TOKEN='a'
#                                     TOKEN='>'
#                                     value_type
#                                       TOKEN='b'
#                                   TOKEN=')'
#                               ifel_body
#                                 TOKEN='{'
#                                 code
#                                   init
#                                     data_type
#                                       TOKEN='Rectangle'
#                                     TOKEN='rectTwo'
#                                 TOKEN='}'
#                             else_cond
#                               TOKEN='else'
#                               ifel_body
#                                 TOKEN='{'
#                                 code
#                                   init
#                                     data_type
#                                       TOKEN='Arc'
#                                     TOKEN='arcOne'
#                                 TOKEN='}'
#                         TOKEN='}'
#                   TOKEN='}'
#           TOKEN='}'
#     code
#       math_expr
#         TOKEN='ab'
#         TOKEN='='
#         computation
#           value_type
#             TOKEN='1'
#           TOKEN='+'
#           value_type
#             TOKEN='ab'
#     code
#       size_shape
#         TOKEN='rect'
#         TOKEN='.'
#         TOKEN='size'
#         TOKEN='('
#         size_params
#           two_params
#             value_type
#               TOKEN='10'
#             TOKEN=','
#             value_type
#               TOKEN='20'
#           TOKEN=','
#           two_params
#             value_type
#               TOKEN='20'
#             TOKEN=','
#             value_type
#               TOKEN='40'
#         TOKEN=')'
#     code
#       size_shape
#         TOKEN='circle'
#         TOKEN='.'
#         TOKEN='size'
#         TOKEN='('
#         size_params
#           two_params
#             value_type
#               TOKEN='50'
#             TOKEN=','
#             value_type
#               TOKEN='50'
#           TOKEN=','
#           value_type
#             TOKEN='20'
#         TOKEN=')'
#     code
#       size_shape
#         TOKEN='dot'
#         TOKEN='.'
#         TOKEN='size'
#         TOKEN='('
#         size_params
#           two_params
#             value_type
#               TOKEN='50'
#             TOKEN=','
#             value_type
#               TOKEN='50'
#         TOKEN=')'
#     TOKEN='}'
