# %%
# import the tokenizer module
# access interface functions using tk
import tokenizer as tk   
from parse import Parse
from interpreter import Interpreter

# %%
# Tokenize code lines on 'sample.art' source file
tokendf = tk.Tokenize('sample.art')
tokendf     # display tokenlist dataframe
# Out:
#      lineNumber  start      token          type
# 0             1      0        def           DEF
# 1             1      4     sample    IDENTIFIER
# 2             1     10          (   PAREN_START
# 3             1     11          a    IDENTIFIER
# 4             1     12          ,     SEPARATOR
# 5             1     13          b    IDENTIFIER
# 6             1     14          )     PAREN_END
# 7             1     15          {   CURLY_START
# 8             2      0      Pixel         PIXEL
# 9             2      6        ctr    IDENTIFIER
# 10            3      0      Pixel         PIXEL
# 11            3      6         px    IDENTIFIER
# 12            4      0         px    IDENTIFIER
# 13            4      3          =     ASSIGN_OP
# 14            4      5         10       INTEGER
# 15            5      0        for           FOR
# 16            5      3          (   PAREN_START
# 17            5      4        ctr    IDENTIFIER
# 18            5      8          =     ASSIGN_OP
# 19            5     10          0       INTEGER
# 20            5     11          ;   SEMICOL_SEP
# 21            5     13        ctr    IDENTIFIER
# 22            5     17         <=       COND_OP
# 23            5     20         10       INTEGER
# 24            5     22          ;   SEMICOL_SEP
# 25            5     24          2       INTEGER
# 26            5     25         ++     INCDEC_OP
# 27            5     27          )     PAREN_END
# 28            5     28          {   CURLY_START
# 29            6      0         px    IDENTIFIER
# 30            6      3          =     ASSIGN_OP
# 31            6      5         px    IDENTIFIER
# 32            6      8          +     INCDEC_OP
# 33            6     10        ctr    IDENTIFIER
# 34            7      0        smp    IDENTIFIER
# 35            7      3          .  DOT_NOTATION
# 36            7      4       size          SIZE
# 37            7      8          (   PAREN_START
# 38            7      9         10       INTEGER
# 39            7     11          ,     SEPARATOR
# 40            7     13         20       INTEGER
# 41            7     15          ,     SEPARATOR
# 42            7     17         20       INTEGER
# 43            7     19          ,     SEPARATOR
# 44            7     21         px    IDENTIFIER
# 45            7     23          )     PAREN_END
# 46            8      0          }     CURLY_END
# 47           10      0     return    IDENTIFIER
# 48           10      7         px    IDENTIFIER
# 49           11      0          }     CURLY_END
# 50           13      0        def           DEF
# 51           13      4   funcName    IDENTIFIER
# 52           13     12          (   PAREN_START
# 53           13     13          )     PAREN_END
# 54           13     14          {   CURLY_START
# 55           14      0     canvas        CANVAS
# 56           14      6          (   PAREN_START
# 57           14      7         50       INTEGER
# 58           14      9          ,     SEPARATOR
# 59           14     10         30       INTEGER
# 60           14     12          )     PAREN_END
# 61           15      0  Rectangle     RECTANGLE
# 62           15     10       rect    IDENTIFIER
# 63           16      0     Circle        CIRCLE
# 64           16      7       circ    IDENTIFIER
# 65           17      0       rect    IDENTIFIER
# 66           17      4          .  DOT_NOTATION
# 67           17      5       size          SIZE
# 68           17      9          (   PAREN_START
# 69           17     10         10       INTEGER
# 70           17     12          ,     SEPARATOR
# 71           17     14         20       INTEGER
# 72           17     16          ,     SEPARATOR
# 73           17     18         20       INTEGER
# 74           17     20          ,     SEPARATOR
# 75           17     22         40       INTEGER
# 76           17     24          )     PAREN_END
# 77           18      0       circ    IDENTIFIER
# 78           18      4          .  DOT_NOTATION
# 79           18      5       size          SIZE
# 80           18      9          (   PAREN_START
# 81           18     10         50       INTEGER
# 82           18     12          ,     SEPARATOR
# 83           18     14         50       INTEGER
# 84           18     16          ,     SEPARATOR
# 85           18     18         50       INTEGER
# 86           18     20          )     PAREN_END
# 87           19      0  Rectangle     RECTANGLE
# 88           19     10        smp    IDENTIFIER
# 89           20      0         if            IF
# 90           20      2          (   PAREN_START
# 91           20      3          1       INTEGER
# 92           20      5          <       COND_OP
# 93           20      7          2       INTEGER
# 94           20      8          )     PAREN_END
# 95           20     10          {   CURLY_START
# 96           21      0        smp    IDENTIFIER
# 97           21      3          .  DOT_NOTATION
# 98           21      4       size          SIZE
# 99           21      8          (   PAREN_START
# 100          21      9         10       INTEGER
# 101          21     11          ,     SEPARATOR
# 102          21     13         20       INTEGER
# 103          21     15          ,     SEPARATOR
# 104          21     17         20       INTEGER
# 105          21     19          ,     SEPARATOR
# 106          21     21         40       INTEGER
# 107          21     23          )     PAREN_END
# 108          22      0          }     CURLY_END
# 109          23      0       elif          ELIF
# 110          23      4          (   PAREN_START
# 111          23      5          2       INTEGER
# 112          23      7          <       COND_OP
# 113          23      9          3       INTEGER
# 114          23     10          )     PAREN_END
# 115          23     11          {   CURLY_START
# 116          24      0        smp    IDENTIFIER
# 117          24      3          .  DOT_NOTATION
# 118          24      4       size          SIZE
# 119          24      8          (   PAREN_START
# 120          24      9         10       INTEGER
# 121          24     11          ,     SEPARATOR
# 122          24     13         20       INTEGER
# 123          24     15          ,     SEPARATOR
# 124          24     17         20       INTEGER
# 125          24     19          ,     SEPARATOR
# 126          24     21         40       INTEGER
# 127          24     23          )     PAREN_END
# 128          25      0          }     CURLY_END
# 129          26      0       else          ELSE
# 130          26      5          {   CURLY_START
# 131          27      0        smp    IDENTIFIER
# 132          27      3          .  DOT_NOTATION
# 133          27      4       size          SIZE
# 134          27      8          (   PAREN_START
# 135          27      9         10       INTEGER
# 136          27     11          ,     SEPARATOR
# 137          27     13         20       INTEGER
# 138          27     15          ,     SEPARATOR
# 139          27     17         20       INTEGER
# 140          27     19          ,     SEPARATOR
# 141          27     21         40       INTEGER
# 142          27     23          )     PAREN_END
# 143          28      0          }     CURLY_END
# 144          30      0      Pixel         PIXEL
# 145          30      6        ctr    IDENTIFIER
# 146          31      0      Pixel         PIXEL
# 147          31      6         px    IDENTIFIER
# 148          32      0         px    IDENTIFIER
# 149          32      3          =     ASSIGN_OP
# 150          32      5         10       INTEGER
# 151          33      0        for           FOR
# 152          33      3          (   PAREN_START
# 153          33      4        ctr    IDENTIFIER
# 154          33      8          =     ASSIGN_OP
# 155          33     10          0       INTEGER
# 156          33     11          ;   SEMICOL_SEP
# 157          33     13        ctr    IDENTIFIER
# 158          33     17         <=       COND_OP
# 159          33     20          5       INTEGER
# 160          33     21          ;   SEMICOL_SEP
# 161          33     23          2       INTEGER
# 162          33     24         ++     INCDEC_OP
# 163          33     26          )     PAREN_END
# 164          33     27          {   CURLY_START
# 165          34      0         px    IDENTIFIER
# 166          34      3          =     ASSIGN_OP
# 167          34      5         px    IDENTIFIER
# 168          34      8          +     INCDEC_OP
# 169          34     10        ctr    IDENTIFIER
# 170          35      0        smp    IDENTIFIER
# 171          35      3          .  DOT_NOTATION
# 172          35      4       size          SIZE
# 173          35      8          (   PAREN_START
# 174          35      9         10       INTEGER
# 175          35     11          ,     SEPARATOR
# 176          35     13         20       INTEGER
# 177          35     15          ,     SEPARATOR
# 178          35     17         20       INTEGER
# 179          35     19          ,     SEPARATOR
# 180          35     21         px    IDENTIFIER
# 181          35     23          )     PAREN_END
# 182          36      0          }     CURLY_END
# 183          37      0          }     CURLY_END
# 184          39      0        def           DEF
# 185          39      4       main    IDENTIFIER
# 186          39      8          (   PAREN_START
# 187          39      9          )     PAREN_END
# 188          39     10          {   CURLY_START
# 189          40      0     canvas        CANVAS
# 190          40      6          (   PAREN_START
# 191          40      7       1000       INTEGER
# 192          40     11          ,     SEPARATOR
# 193          40     12       1000       INTEGER
# 194          40     16          )     PAREN_END
# 195          41      0   funcName    IDENTIFIER
# 196          41      8          (   PAREN_START
# 197          41      9          )     PAREN_END
# 198          42      0          a    IDENTIFIER
# 199          42      2          =     ASSIGN_OP
# 200          42      4          1       INTEGER
# 201          43      0          b    IDENTIFIER
# 202          43      2          =     ASSIGN_OP
# 203          43      4          2       INTEGER
# 204          44      0     sample    IDENTIFIER
# 205          44      6          (   PAREN_START
# 206          44      7          a    IDENTIFIER
# 207          44      8          ,     SEPARATOR
# 208          44     10          b    IDENTIFIER
# 209          44     11          )     PAREN_END
# 210          45      0          }     CURLY_END

# %%
prMod = Parse('sample.art', tokendf)
prMod.Parser()
# Out:
# Parse Tree is displayed below:
# expr
#   func
#     def
#     funcName
#     (
#     )
#     {
#     code
#       canvas_def
#         canvas
#         (
#         two_params
#           value_type
#             50
#           ,
#           value_type
#             30
#         )
#     code
#       init
#         data_type
#           Rectangle
#         rect
#     code
#       init
#         data_type
#           Circle
#         circ
#     code
#       size_shape
#         rect
#         .
#         size
#         (
#         size_params
#           two_params
#             value_type
#               10
#             ,
#             value_type
#               20
#           ,
#           two_params
#             value_type
#               20
#             ,
#             value_type
#               40
#         )
#     code
#       size_shape
#         circ
#         .
#         size
#         (
#         size_params
#           two_params
#             value_type
#               50
#             ,
#             value_type
#               50
#           ,
#           value_type
#             50
#         )
#     code
#       init
#         data_type
#           Rectangle
#         smp
#     code
#       if_else
#         if_cond
#           if
#           condition
#             condition_base
#               (
#               condition_body
#                 value_type
#                   1
#                 <
#                 value_type
#                   2
#               )
#           ifel_body
#             {
#             code
#               size_shape
#                 smp
#                 .
#                 size
#                 (
#                 size_params
#                   two_params
#                     value_type
#                       10
#                     ,
#                     value_type
#                       20
#                   ,
#                   two_params
#                     value_type
#                       20
#                     ,
#                     value_type
#                       40
#                 )
#             }
#         elif_cond
#           elif
#           condition
#             condition_base
#               (
#               condition_body
#                 value_type
#                   2
#                 <
#                 value_type
#                   3
#               )
#           ifel_body
#             {
#             code
#               size_shape
#                 smp
#                 .
#                 size
#                 (
#                 size_params
#                   two_params
#                     value_type
#                       10
#                     ,
#                     value_type
#                       20
#                   ,
#                   two_params
#                     value_type
#                       20
#                     ,
#                     value_type
#                       40
#                 )
#             }
#         else_cond
#           else
#           ifel_body
#             {
#             code
#               size_shape
#                 smp
#                 .
#                 size
#                 (
#                 size_params
#                   two_params
#                     value_type
#                       10
#                     ,
#                     value_type
#                       20
#                   ,
#                   two_params
#                     value_type
#                       20
#                     ,
#                     value_type
#                       40
#                 )
#             }
#     code
#       init
#         data_type
#           Pixel
#         ctr
#     code
#       init
#         data_type
#           Pixel
#         px
#     code
#       init_int
#         px
#         =
#         10
#     code
#       loop
#         for
#         (
#         loop_init
#           init_int
#             ctr
#             =
#             0
#           ;
#         loop_cond
#           condition_body
#             value_type
#               ctr
#             <=
#             value_type
#               5
#           ;
#         loop_incdec
#           2
#           ++
#         )
#         loop_body
#           {
#           code
#             math_expr
#               px
#               =
#               computation
#                 value_type
#                   px
#                 +
#                 value_type
#                   ctr
#           code
#             size_shape
#               smp
#               .
#               size
#               (
#               size_params
#                 two_params
#                   value_type
#                     10
#                   ,
#                   value_type
#                     20
#                 ,
#                 two_params
#                   value_type
#                     20
#                   ,
#                   value_type
#                     px
#               )
#           }
#     }
#   func
#     def
#     main
#     (
#     )
#     {
#     code
#       canvas_def
#         canvas
#         (
#         two_params
#           value_type
#             1000
#           ,
#           value_type
#             1000
#         )
#     code
#       func_call
#         funcName
#         (
#         )
#     }

# %%
import tokenizer as tk   
from parse import Parse
from interpreter import Interpreter

intptr = Interpreter(tokendf)
intptr.Interpret()
# intptr.Build()
