# %%
# import the tokenizer module
# access interface functions using tk
import tokenizer as tk   
from parse import Parse
from interpreter import Interpreter

# %%
# Tokenize code lines on 'sample.art' source file
tokendf = tk.Tokenize('sample.art')
#tokendf     # display tokenlist dataframe

# %%
prMod = Parse('sample.art', tokendf)
prMod.Parser()
# Out:
# line 28:12 token recognition error at: '/'
# line 28:14 extraneous input '45' expecting {RECTANGLE, SQUARE, CIRCLE, DOT, STRAIGHT, ARC, PIXEL, IF, FOR, CANVAS, IDENTIFIER, '}'}
# line 26:26 Identifier x is not declared
# line 27:27 Identifier y is not declared
# line 28:28 Identifier y is not declared
# line 29:29 Identifier y is not declared
# line 31:31 Identifier y is not declared
#
#
# Parse Tree is displayed below:
# expr
#   func
#     def
#     funcName
#     (
#     )
#     {
#     code
#       canvas_def
#         canvas
#         (
#         two_params
#           value_type
#             50
#           ,
#           value_type
#             30
#         )
#     code
#       init
#         data_type
#           Rectangle
#         rect
#     code
#       init
#         data_type
#           Circle
#         circ
#     code
#       size_shape
#         rect
#         .
#         size
#         (
#         size_params
#           two_params
#             value_type
#               10
#             ,
#             value_type
#               20
#           ,
#           two_params
#             value_type
#               20
#             ,
#             value_type
#               40
#         )
#     code
#       size_shape
#         circ
#         .
#         size
#         (
#         size_params
#           two_params
#             value_type
#               50
#             ,
#             value_type
#               50
#           ,
#           value_type
#             50
#         )
#     code
#       init
#         data_type
#           Rectangle
#         smp
#     code
#       if_else
#         if_cond
#           if
#           condition
#             condition_base
#               (
#               condition_body
#                 value_type
#                   1
#                 <
#                 value_type
#                   2
#               )
#           ifel_body
#             {
#             code
#               size_shape
#                 smp
#                 .
#                 size
#                 (
#                 size_params
#                   two_params
#                     value_type
#                       10
#                     ,
#                     value_type
#                       20
#                   ,
#                   two_params
#                     value_type
#                       20
#                     ,
#                     value_type
#                       40
#                 )
#             }
#         elif_cond
#           elif
#           condition
#             condition_base
#               (
#               condition_body
#                 value_type
#                   2
#                 <
#                 value_type
#                   3
#               )
#           ifel_body
#             {
#             code
#               size_shape
#                 smp
#                 .
#                 size
#                 (
#                 size_params
#                   two_params
#                     value_type
#                       10
#                     ,
#                     value_type
#                       20
#                   ,
#                   two_params
#                     value_type
#                       20
#                     ,
#                     value_type
#                       40
#                 )
#             }
#         else_cond
#           else
#           ifel_body
#             {
#             code
#               size_shape
#                 smp
#                 .
#                 size
#                 (
#                 size_params
#                   two_params
#                     value_type
#                       10
#                     ,
#                     value_type
#                       20
#                   ,
#                   two_params
#                     value_type
#                       20
#                     ,
#                     value_type
#                       40
#                 )
#             }
#     code
#       init
#         data_type
#           Pixel
#         ctr
#     code
#       init
#         data_type
#           Pixel
#         px
#     code
#       init_int
#         px
#         =
#         10
#     code
#       loop
#         for
#         (
#         loop_init
#           init_int
#             ctr
#             =
#             0
#           ;
#         loop_cond
#           condition_body
#             value_type
#               ctr
#             <=
#             value_type
#               5
#           ;
#         loop_incdec
#           2
#           ++
#         )
#         loop_body
#           {
#           code
#             math_expr
#               px
#               =
#               computation
#                 value_type
#                   px
#                 +
#                 value_type
#                   ctr
#           code
#             size_shape
#               smp
#               .
#               size
#               (
#               size_params
#                 two_params
#                   value_type
#                     10
#                   ,
#                   value_type
#                     20
#                 ,
#                 two_params
#                   value_type
#                     20
#                   ,
#                   value_type
#                     px
#               )
#           }
#     code
#       init_int
#         x
#         =
#         5
#     code
#       math_expr
#         y
#         =
#         computation
#           value_type
#             123
#           *
#           value_type
#             45
#     code
#       init_int
#         y
#         =
#         123
#     45
#     code
#       math_expr
#         y
#         =
#         computation
#           value_type
#             123
#           +
#           value_type
#             45
#     code
#       math_expr
#         z
#         --
#     code
#       math_expr
#         y
#         =
#         computation
#           value_type
#             123
#           -
#           value_type
#             45
#     code
#       math_expr
#         z
#         ++
#     code
#       fill_def
#         rect
#         .
#         fill
#         (
#         fill_params
#           rgb_def
#             rgb
#             (
#             two_params
#               value_type
#                 0
#               ,
#               value_type
#                 0
#             ,
#             value_type
#               0
#             )
#           ,
#           value_type
#             50
#         )
#     }
#   func
#     def
#     main
#     (
#     )
#     {
#     code
#       canvas_def
#         canvas
#         (
#         two_params
#           value_type
#             1000
#           ,
#           value_type
#             1000
#         )
#     code
#       func_call
#         funcName
#         (
#         )
#     }

# %%
intptr = Interpreter(tokendf)
intptr.Interpret()
intptr.Build()
# Out:
# rect 0 0 0 50

# %%
for i in range(len(intptr.tokens)):
    print("{0:20} {1}".format(
            intptr.tokens[i]["type"],
            intptr.tokens[i]["token"])
         )
# Out:
# DEF                  def
# IDENTIFIER           funcName
# PAREN_START          (
# PAREN_END            )
# CURLY_START          {
# CANVAS               canvas
# PAREN_START          (
# INTEGER              50
# SEPARATOR            ,
# INTEGER              30
# PAREN_END            )
# RECTANGLE            Rectangle
# IDENTIFIER           rect
# CIRCLE               Circle
# IDENTIFIER           circ
# IDENTIFIER           rect
# DOT_NOTATION         .
# SIZE                 size
# PAREN_START          (
# INTEGER              10
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              40
# PAREN_END            )
# IDENTIFIER           circ
# DOT_NOTATION         .
# SIZE                 size
# PAREN_START          (
# INTEGER              50
# SEPARATOR            ,
# INTEGER              50
# SEPARATOR            ,
# INTEGER              50
# PAREN_END            )
# RECTANGLE            Rectangle
# IDENTIFIER           smp
# IF                   if
# PAREN_START          (
# INTEGER              1
# COND_OP              <
# INTEGER              2
# PAREN_END            )
# CURLY_START          {
# IDENTIFIER           smp
# DOT_NOTATION         .
# SIZE                 size
# PAREN_START          (
# INTEGER              10
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              40
# PAREN_END            )
# CURLY_END            }
# ELIF                 elif
# PAREN_START          (
# INTEGER              2
# COND_OP              <
# INTEGER              3
# PAREN_END            )
# CURLY_START          {
# IDENTIFIER           smp
# DOT_NOTATION         .
# SIZE                 size
# PAREN_START          (
# INTEGER              10
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              40
# PAREN_END            )
# CURLY_END            }
# ELSE                 else
# CURLY_START          {
# IDENTIFIER           smp
# DOT_NOTATION         .
# SIZE                 size
# PAREN_START          (
# INTEGER              10
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              40
# PAREN_END            )
# CURLY_END            }
# PIXEL                Pixel
# IDENTIFIER           ctr
# PIXEL                Pixel
# IDENTIFIER           px
# IDENTIFIER           px
# ASSIGN_OP            =
# INTEGER              10
# FOR                  for
# PAREN_START          (
# IDENTIFIER           ctr
# ASSIGN_OP            =
# INTEGER              0
# SEMICOL_SEP          ;
# IDENTIFIER           ctr
# COND_OP              <=
# INTEGER              5
# SEMICOL_SEP          ;
# INTEGER              2
# INCDEC_OP            ++
# PAREN_END            )
# CURLY_START          {
# IDENTIFIER           px
# ASSIGN_OP            =
# IDENTIFIER           px
# MATH_OP              +
# IDENTIFIER           ctr
# IDENTIFIER           smp
# DOT_NOTATION         .
# SIZE                 size
# PAREN_START          (
# INTEGER              10
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# INTEGER              20
# SEPARATOR            ,
# IDENTIFIER           px
# PAREN_END            )
# CURLY_END            }
# IDENTIFIER           x
# ASSIGN_OP            =
# INTEGER              5
# IDENTIFIER           y
# ASSIGN_OP            =
# INTEGER              123
# MATH_OP              *
# INTEGER              45
# IDENTIFIER           y
# ASSIGN_OP            =
# INTEGER              123
# MATH_OP              /
# INTEGER              45
# IDENTIFIER           y
# ASSIGN_OP            =
# INTEGER              123
# MATH_OP              +
# INTEGER              45
# IDENTIFIER           z
# INCDEC_OP            --
# IDENTIFIER           y
# ASSIGN_OP            =
# INTEGER              123
# MATH_OP              -
# INTEGER              45
# IDENTIFIER           z
# INCDEC_OP            ++
# IDENTIFIER           rect
# DOT_NOTATION         .
# FILL                 fill
# PAREN_START          (
# RGB                  rgb
# PAREN_START          (
# INTEGER              0
# SEPARATOR            ,
# INTEGER              0
# SEPARATOR            ,
# INTEGER              0
# PAREN_END            )
# SEPARATOR            ,
# INTEGER              50
# PAREN_END            )
# CURLY_END            }
# DEF                  def
# IDENTIFIER           main
# PAREN_START          (
# PAREN_END            )
# CURLY_START          {
# CANVAS               canvas
# PAREN_START          (
# INTEGER              1000
# SEPARATOR            ,
# INTEGER              1000
# PAREN_END            )
# IDENTIFIER           funcName
# PAREN_START          (
# PAREN_END            )
# CURLY_END            }
